# %%
import os, json
from pathlib import Path, PureWindowsPath # for Unix compatibility

from cri.robot import SyncRobot
from cri.controller import Mg400Controller as Controller
from vsp.video_stream import CvImageOutputFileSeq, CvVideoDisplay, CvPreprocVideoCamera   
from vsp.processor import CameraStreamProcessor, AsyncProcessor

from pose_models_2d.lib.common import make_target_df, home, collect

data_path = os.path.join(os.environ["DATAPATH"], "open", "tactile-servoing-2d-dobot")

# %%
# User-defined paths
data_dir = os.path.join("digitac", "model_surface2d")

# Make the new meta dictionary
meta = {
    # ~~~~~~~~~ Paths ~~~~~~~~~#
    "meta_file": os.path.join(data_dir, "meta.json"),
    "image_dir": os.path.join(data_dir, "frames_bw"), # to store tactile images
    "target_df_file": os.path.join(data_dir, "targets.csv"), # to store labels
    # ~~~~~~~~~ Robot movements ~~~~~~~~~#
    "home_pose": [330, -100, -100, 0, 0, 0],  
    "linear_speed": 10,
    "angular_speed": 10,
    "tap_move": [0, 5, 0, 0, 0, 0], # move to sheared-pose
    "poses_rng": [[0, 2, 0, 0, 0, 30], [0, -2, 0, 0, 0, -30]], # range to gather poses
    "moves_rng": [[5, 0, 0, 0, 0, 5], [-5, 0, 0, 0, 0, -5]],  # range to shear poses
    "num_poses": 5000,  
    # ~~ TacTip ~~
    # "robot_tcp": [0, -38, 0, 0, 0, 0],  
    # "work_frame": [330, -90+38, -140, 0, 0, 12],
    # ~~ DigiTac ~~
    "robot_tcp": [0, -24, 0, 0, 0, 0],  
    "work_frame": [330, -78+24, -150, 0, 0, -8],  
    # ~~~~~~~~~ Camera Settings ~~~~~~~~~#
    "source": 0, # which usb camera (0,1,2) CHECK IF CODE FAILS        
    "num_frames": 1, # frames per tap
    "threshold": [61, -5], # comment if DIGIT for greyscale image 
    "exposure": -7,  
    # ~~ TacTip ~~
    # "crop": [320-128-10, 240-128+5, 320+128-10, 240+128+5],
    # "size": [256, 256], 
    # ~~ DigiTac/DIGIT ~~
    "crop": [320-320, 240-240, 320+320, 240+240],
    "size": [640, 480], 
    # ~~~~~~~~~ Comments ~~~~~~~~~#
    "comments": "gather digit training data for pose of 2d square planar surface"
    }

# %%
# Save dictionary to file
os.makedirs(os.path.join(data_path, data_dir), exist_ok=True)
with open(os.path.join(data_path, meta["meta_file"]), 'w') as f:
    json.dump(meta, f)

# Absolute posix paths
for key in [k for k in meta.keys() if "file" in k or "dir" in k]:
    meta[key] = os.path.join(data_path, meta[key])
    meta[key] = Path(PureWindowsPath(meta[key])).as_posix() # for Unix

# Make target_df
target_df = make_target_df(**meta)

# %%
def make_sensor(size, crop, threshold, exposure, source, **kwargs):  # amcap: reset all settings; autoexposure off; saturdation max
    camera = CvPreprocVideoCamera(size, crop, threshold, exposure=exposure, source=source)
    for _ in range(5): camera.read() # Hack - camera transient   
    return AsyncProcessor(CameraStreamProcessor(camera=camera,
            display=CvVideoDisplay(name='sensor'),
            writer=CvImageOutputFileSeq()))

# %%
with SyncRobot(Controller()) as robot, make_sensor(**meta) as sensor:    
    home(robot, **meta)   
    collect(robot, sensor, target_df, **meta)
# Out:
# Collecting data for object 1, pose 1: ...
# pose = [  0   -0.82   0    0    0  -29.93]
# joints=[-14.73  64.28  68.26   2.82]
# Collecting data for object 1, pose 2: ...
# pose = [  0    1.1    0    0    0  -27.65]
# joints=[-14.73  64.28  68.26   2.82]
# Collecting data for object 1, pose 3: ...
# pose = [  0   -1.51   0    0    0  -26.96]
# joints=[-14.73  64.28  68.26   2.82]
# Collecting data for object 1, pose 4: ...
# pose = [  0    1.27   0    0    0  -26.43]
# joints=[-14.73  64.28  68.26   2.82]
# Collecting data for object 1, pose 5: ...
# pose = [  0    0.83   0    0    0  -25.77]
# joints=[-14.73  64.28  68.26   2.82]
# Collecting data for object 1, pose 6: ...
# pose = [  0    0.94   0    0    0  -25.76]
# joints=[-14.73  64.28  68.26   2.82]
# Collecting data for object 1, pose 7: ...
# pose = [  0    1.73   0    0    0  -23.8 ]
# joints=[-14.73  64.28  68.26   2.82]
# Collecting data for object 1, pose 8: ...
# pose = [  0    0.27   0    0    0  -23.52]
# joints=[-14.73  64.28  68.26   2.82]
# Collecting data for object 1, pose 9: ...
# pose = [  0    0.47   0    0    0  -22.36]
# joints=[-14.73  64.28  68.26   2.82]
# Collecting data for object 1, pose 10: ...
# pose = [  0   -1.2    0    0    0  -20.94]
# joints=[-14.73  64.28  68.26   2.82]
# Collecting data for object 1, pose 11: ...
# pose = [  0   -1.47   0    0    0  -20.88]
# joints=[-14.73  64.28  68.26   2.82]
# Collecting data for object 1, pose 12: ...
# pose = [  0   -1.7    0    0    0  -19.96]
# joints=[-14.73  64.28  68.26   2.82]
# Collecting data for object 1, pose 13: ...
# pose = [  0   -1.48   0    0    0  -16.83]
# joints=[-14.73  64.28  68.26   2.82]
# Collecting data for object 1, pose 14: ...
# pose = [  0    1.13   0    0    0  -15.5 ]
# joints=[-14.73  64.28  68.26   2.82]
# Collecting data for object 1, pose 15: ...
# pose = [  0    0.41   0    0    0  -11.55]
# joints=[-14.73  64.28  68.26   2.82]
# Collecting data for object 1, pose 16: ...
# pose = [  0    1.53   0    0    0  -11.55]
# joints=[-14.73  64.28  68.26   2.82]
# Collecting data for object 1, pose 17: ...
# pose = [ 0   0.81  0   0   0  -9.19]
# joints=[-14.73  64.28  68.26   2.82]
# Collecting data for object 1, pose 18: ...
# pose = [ 0  -0.86  0   0   0  -8.75]
# joints=[-14.73  64.28  68.26   2.82]
# Collecting data for object 1, pose 19: ...
# pose = [ 0  -1.1   0   0   0  -7.06]
# joints=[-14.73  64.28  68.26   2.82]
# Collecting data for object 1, pose 20: ...
# pose = [ 0  -0.49  0   0   0  -6.84]
# joints=[-14.73  64.28  68.26   2.82]
# Collecting data for object 1, pose 21: ...
# pose = [ 0  -0.01  0   0   0  -6.38]
# joints=[-14.73  64.28  68.26   2.82]
# Collecting data for object 1, pose 22: ...
# pose = [ 0   0.3   0   0   0  -5.21]
# joints=[-14.73  64.28  68.26   2.82]
# Collecting data for object 1, pose 23: ...
# pose = [ 0  -0.99  0   0   0  -5.07]
# joints=[-14.73  64.28  68.26   2.82]
# Collecting data for object 1, pose 24: ...
# pose = [ 0  -1.85  0   0   0  -4.34]
# joints=[-14.73  64.28  68.26   2.82]
# Collecting data for object 1, pose 25: ...
# pose = [ 0  -1.57  0   0   0  -1.73]
# joints=[-14.73  64.28  68.26   2.82]
# Collecting data for object 1, pose 26: ...
# pose = [ 0  -1.14  0   0   0   0.86]
# joints=[-14.73  64.28  68.26   2.82]
# Collecting data for object 1, pose 27: ...
# pose = [0  1.95 0  0  0  1.3 ]
# joints=[-14.73  64.28  68.26   2.82]
# Collecting data for object 1, pose 28: ...
# pose = [0  1.61 0  0  0  1.88]
# joints=[-14.73  64.28  68.26   2.82]
# Collecting data for object 1, pose 29: ...
# pose = [ 0  -0.28  0   0   0   2.79]
# joints=[-14.73  64.28  68.26   2.82]
# Collecting data for object 1, pose 30: ...
# pose = [ 0  -0.47  0   0   0   3.78]
# joints=[-14.73  64.28  68.26   2.82]
# Collecting data for object 1, pose 31: ...
# pose = [0  0.79 0  0  0  4.27]
# joints=[-14.73  64.28  68.26   2.82]
# Collecting data for object 1, pose 32: ...
# pose = [ 0  -0.56  0   0   0   5.12]
# joints=[-14.73  64.28  68.26   2.82]
# Collecting data for object 1, pose 33: ...
# pose = [0  1.53 0  0  0  6.24]
# joints=[-14.73  64.28  68.26   2.82]
# Collecting data for object 1, pose 34: ...
# pose = [0  1.56 0  0  0  7.88]
# joints=[-14.73  64.28  68.26   2.82]
# Collecting data for object 1, pose 35: ...
# pose = [ 0  -1.47  0   0   0   8.4 ]
# joints=[-14.73  64.28  68.26   2.93]
# Collecting data for object 1, pose 36: ...
# pose = [ 0  -1.81  0   0   0  12.15]
# joints=[-14.73  64.28  68.26   2.93]
# Collecting data for object 1, pose 37: ...
# pose = [ 0   1.92  0   0   0  13.8 ]
# joints=[-14.73  64.28  68.26   2.93]
# Collecting data for object 1, pose 38: ...
# pose = [ 0  -1.78  0   0   0  14.74]
# joints=[-14.73  64.28  68.26   2.93]
# Collecting data for object 1, pose 39: ...
# pose = [ 0   1.35  0   0   0  15.33]
# joints=[-14.73  64.28  68.26   2.93]
# Collecting data for object 1, pose 40: ...
# pose = [ 0  -1.19  0   0   0  17.07]
# joints=[-14.73  64.28  68.26   2.93]
# Collecting data for object 1, pose 41: ...
# pose = [ 0  -0.36  0   0   0  17.41]
# joints=[-14.73  64.28  68.26   2.93]
# Collecting data for object 1, pose 42: ...
# pose = [ 0  -0.56  0   0   0  18.61]
# joints=[-14.73  64.28  68.26   2.93]
# Collecting data for object 1, pose 43: ...
# pose = [ 0  -0.67  0   0   0  19.01]
# joints=[-14.73  64.28  68.26   2.93]
# Collecting data for object 1, pose 44: ...
# pose = [ 0   0.26  0   0   0  19.22]
# joints=[-14.73  64.28  68.26   2.93]
# Collecting data for object 1, pose 45: ...
# pose = [ 0   1.76  0   0   0  22.26]
# joints=[-14.73  64.28  68.26   2.93]
# Collecting data for object 1, pose 46: ...
# pose = [ 0  -0.42  0   0   0  22.79]
# joints=[-14.73  64.28  68.26   2.93]
# Collecting data for object 1, pose 47: ...
# pose = [ 0   0.55  0   0   0  23.88]
# joints=[-14.73  64.28  68.26   2.93]
# Collecting data for object 1, pose 48: ...
# pose = [ 0   1.1   0   0   0  28.09]
# joints=[-14.73  64.28  68.26   2.93]
# Collecting data for object 1, pose 49: ...
# pose = [ 0  -0.92  0   0   0  28.46]
# joints=[-14.73  64.28  68.26   2.93]
# Collecting data for object 1, pose 50: ...
# pose = [ 0   1.31  0   0   0  28.89]
# joints=[-14.73  64.28  68.26   2.93]
# Disconnecting Dobot...
